# %%
from dataset import ari_to_features
import pandas as pd
import re
from tqdm import tqdm

# %%
dataPath = '../data/dataset.csv'
df = pd.read_csv(dataPath)
df.head()
# Out:
#    Unnamed: 0   artist_name                             track_uri  \
# 0           0   Kadie Elder  spotify:track:72ey4Cr2eXXwH9IMlhzuCV
# 1           1    Matt Alber  spotify:track:3vsHwtwcRXjwejyfKgj6dX
# 2           2   Steve Grand  spotify:track:7i2xzOJU1O7hrP8kqqBchZ
# 3           3  Adam Lambert  spotify:track:44aN5xKL3kGHvQ5bXVk6B8
# 4           4         Queen  spotify:track:09jZZLarDD6MI3eT3ujsEL
#
#                               artist_uri                  track_name  \
# 0  spotify:artist:6y2lKfMfaxfcEmHwU058FG  First Time He Kissed a Boy
# 1  spotify:artist:3v2p34eAq6fINTEyJ1w2vK                Handsome Man
# 2  spotify:artist:0oqk73d6vKVx8Ekz4onThW            All-American Boy
# 3  spotify:artist:6prmLEyn4LfHlD9NnXWlf7                  Ghost Town
# 4  spotify:artist:1dfeR4HaWDbWqFHLkxsg1d        I Want To Break Free
#
#                               album_uri  duration  \
# 0  spotify:album:1GYbbLzBosZi7MLG12iasq    187977
# 1  spotify:album:5ysULa9YY0ccEAZtxklzln    240920
# 2  spotify:album:40nTEfg3tTj1bptrG7IQU0    297410
# 3  spotify:album:3kaQUt8Mp906u1fI0LDqO6    208330
# 4  spotify:album:5Ck5a5KpFGdl6evWX5ENo8    200973
#
#                            album_name       artists
# 0          First Time He Kissed a Boy   Kadie Elder
# 1                     Wind Sand Stars    Matt Alber
# 2                    All American Boy   Steve Grand
# 3  The Original High (Deluxe Version)  Adam Lambert
# 4                           The Works         Queen

# %%
df["track_uri"] = df["track_uri"].apply(lambda x: re.findall(r'\w+$', x)[0])
df["track_uri"]
# Out:
# 0      72ey4Cr2eXXwH9IMlhzuCV
# 1      3vsHwtwcRXjwejyfKgj6dX
# 2      7i2xzOJU1O7hrP8kqqBchZ
# 3      44aN5xKL3kGHvQ5bXVk6B8
# 4      09jZZLarDD6MI3eT3ujsEL
#                 ...
# 578    5TK55y7SXDt36Fi14WBG8X
# 579    2nTu3jikKUP01bD5GkxgoD
# 580    7uoQRNx100em2FLLxnqym0
# 581    3V3iy4K6paycRmTyrjQVwi
# 582    11ztTGjFtV3MNoNx0XvApC
# Name: track_uri, Length: 583, dtype: object

# %%
ari_to_features(df['track_uri'][0])
# Out:
# {'danceability': 0.616,
#  'energy': 0.856,
#  'key': 11,
#  'loudness': -4.901,
#  'mode': 0,
#  'speechiness': 0.0389,
#  'acousticness': 0.0238,
#  'instrumentalness': 0,
#  'liveness': 0.598,
#  'valence': 0.63,
#  'tempo': 107.013,
#  'type': 'audio_features',
#  'id': '72ey4Cr2eXXwH9IMlhzuCV',
#  'uri': 'spotify:track:72ey4Cr2eXXwH9IMlhzuCV',
#  'track_href': 'https://api.spotify.com/v1/tracks/72ey4Cr2eXXwH9IMlhzuCV',
#  'analysis_url': 'https://api.spotify.com/v1/audio-analysis/72ey4Cr2eXXwH9IMlhzuCV',
#  'duration_ms': 187978,
#  'time_signature': 4,
#  'artist_pop': 26,
#  'genres': 'unknown',
#  'track_pop': 44}

# %%
datalist=df['track_uri'].unique()
featureLIST=[]
for i in tqdm([uri for uri in datalist]):
    try:
        featureLIST.append(ari_to_features(i))
    except:
        continue
# Out:
# 100%|██████████| 556/556 [10:08<00:00,  1.09s/it]

# %%
featureDF = pd.DataFrame(featureLIST)
featureDF
# Out:
#      danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0           0.616   0.856   11    -4.901     0       0.0389      0.023800
# 1           0.319   0.176    7   -11.104     1       0.0393      0.863000
# 2           0.441   0.709    6    -3.910     1       0.0333      0.084000
# 3           0.703   0.736    4    -5.709     0       0.0460      0.186000
# 4           0.862   0.402    4   -12.075     1       0.0368      0.047800
# ..            ...     ...  ...       ...   ...          ...           ...
# 551         0.600   0.654    5    -8.896     0       0.0269      0.089100
# 552         0.543   0.617    6    -8.874     0       0.0341      0.063400
# 553         0.479   0.854   11    -6.101     1       0.0405      0.000005
# 554         0.789   0.555    0    -5.900     1       0.0410      0.026000
# 555         0.606   0.284    2    -9.131     0       0.0400      0.705000
#
#      instrumentalness  liveness  valence  ...            type  \
# 0            0.000000    0.5980    0.630  ...  audio_features
# 1            0.000000    0.1060    0.306  ...  audio_features
# 2            0.000000    0.0851    0.280  ...  audio_features
# 3            0.000019    0.1740    0.274  ...  audio_features
# 4            0.004990    0.1790    0.812  ...  audio_features
# ..                ...       ...      ...  ...             ...
# 551          0.000026    0.1310    0.354  ...  audio_features
# 552          0.613000    0.1140    0.434  ...  audio_features
# 553          0.000057    0.3720    0.535  ...  audio_features
# 554          0.000135    0.2150    0.713  ...  audio_features
# 555          0.010400    0.0836    0.153  ...  audio_features
#
#                          id                                   uri  \
# 0    72ey4Cr2eXXwH9IMlhzuCV  spotify:track:72ey4Cr2eXXwH9IMlhzuCV
# 1    3vsHwtwcRXjwejyfKgj6dX  spotify:track:3vsHwtwcRXjwejyfKgj6dX
# 2    7i2xzOJU1O7hrP8kqqBchZ  spotify:track:7i2xzOJU1O7hrP8kqqBchZ
# 3    44aN5xKL3kGHvQ5bXVk6B8  spotify:track:44aN5xKL3kGHvQ5bXVk6B8
# 4    09jZZLarDD6MI3eT3ujsEL  spotify:track:09jZZLarDD6MI3eT3ujsEL
# ..                      ...                                   ...
# 551  5TK55y7SXDt36Fi14WBG8X  spotify:track:5TK55y7SXDt36Fi14WBG8X
# 552  2nTu3jikKUP01bD5GkxgoD  spotify:track:2nTu3jikKUP01bD5GkxgoD
# 553  7uoQRNx100em2FLLxnqym0  spotify:track:7uoQRNx100em2FLLxnqym0
# 554  3V3iy4K6paycRmTyrjQVwi  spotify:track:3V3iy4K6paycRmTyrjQVwi
# 555  11ztTGjFtV3MNoNx0XvApC  spotify:track:11ztTGjFtV3MNoNx0XvApC
#
#                                             track_href  \
# 0    https://api.spotify.com/v1/tracks/72ey4Cr2eXXw...
# 1    https://api.spotify.com/v1/tracks/3vsHwtwcRXjw...
# 2    https://api.spotify.com/v1/tracks/7i2xzOJU1O7h...
# 3    https://api.spotify.com/v1/tracks/44aN5xKL3kGH...
# 4    https://api.spotify.com/v1/tracks/09jZZLarDD6M...
# ..                                                 ...
# 551  https://api.spotify.com/v1/tracks/5TK55y7SXDt3...
# 552  https://api.spotify.com/v1/tracks/2nTu3jikKUP0...
# 553  https://api.spotify.com/v1/tracks/7uoQRNx100em...
# 554  https://api.spotify.com/v1/tracks/3V3iy4K6payc...
# 555  https://api.spotify.com/v1/tracks/11ztTGjFtV3M...
#
#                                           analysis_url duration_ms  \
# 0    https://api.spotify.com/v1/audio-analysis/72ey...      187978
# 1    https://api.spotify.com/v1/audio-analysis/3vsH...      240920
# 2    https://api.spotify.com/v1/audio-analysis/7i2x...      297410
# 3    https://api.spotify.com/v1/audio-analysis/44aN...      208330
# 4    https://api.spotify.com/v1/audio-analysis/09jZ...      200973
# ..                                                 ...         ...
# 551  https://api.spotify.com/v1/audio-analysis/5TK5...      281773
# 552  https://api.spotify.com/v1/audio-analysis/2nTu...      267280
# 553  https://api.spotify.com/v1/audio-analysis/7uoQ...      230560
# 554  https://api.spotify.com/v1/audio-analysis/3V3i...      223405
# 555  https://api.spotify.com/v1/audio-analysis/11zt...      187467
#
#      time_signature  artist_pop  \
# 0                 4          26
# 1                 4          23
# 2                 4          25
# 3                 4          61
# 4                 4          83
# ..              ...         ...
# 551               4          49
# 552               4          37
# 553               4          54
# 554               4          50
# 555               4          38
#
#                                                 genres track_pop
# 0                                              unknown        44
# 1                                              unknown        20
# 2                                        queer_country        34
# 3                     dance_pop idol pop post-teen_pop        67
# 4                          classic_rock glam_rock rock        53
# ..                                                 ...       ...
# 551  canadian_country canadian_pop canadian_singer-...        33
# 552  auteur-compositeur-interprete_quebecois french...         6
# 553  australian_indie indie_pop indie_rock melbourn...         0
# 554                                     neo_mellow pop        47
# 555     contemporary_country country_pop queer_country        31
#
# [556 rows x 21 columns]

# %%
testDF=df
testDF
# Out:
#      Unnamed: 0       artist_name               track_uri  \
# 0             0       Kadie Elder  72ey4Cr2eXXwH9IMlhzuCV
# 1             1        Matt Alber  3vsHwtwcRXjwejyfKgj6dX
# 2             2       Steve Grand  7i2xzOJU1O7hrP8kqqBchZ
# 3             3      Adam Lambert  44aN5xKL3kGHvQ5bXVk6B8
# 4             4             Queen  09jZZLarDD6MI3eT3ujsEL
# ..          ...               ...                     ...
# 578         578         k.d. lang  5TK55y7SXDt36Fi14WBG8X
# 579         579    Ariane Moffatt  2nTu3jikKUP01bD5GkxgoD
# 580         580  Courtney Barnett  7uoQRNx100em2FLLxnqym0
# 581         581      Mary Lambert  3V3iy4K6paycRmTyrjQVwi
# 582         582      Brandy Clark  11ztTGjFtV3MNoNx0XvApC
#
#                                 artist_uri                         track_name  \
# 0    spotify:artist:6y2lKfMfaxfcEmHwU058FG         First Time He Kissed a Boy
# 1    spotify:artist:3v2p34eAq6fINTEyJ1w2vK                       Handsome Man
# 2    spotify:artist:0oqk73d6vKVx8Ekz4onThW                   All-American Boy
# 3    spotify:artist:6prmLEyn4LfHlD9NnXWlf7                         Ghost Town
# 4    spotify:artist:1dfeR4HaWDbWqFHLkxsg1d               I Want To Break Free
# ..                                     ...                                ...
# 578  spotify:artist:6W1BHDF0T4a4KYcSwzD586                   Constant Craving
# 579  spotify:artist:5x9UA1g9OYt1wCyPb0YN8l                 Walls of the World
# 580  spotify:artist:4OOlG5eBXSkSAAEeKjJb5Y                 Pedestrian at Best
# 581  spotify:artist:5Z2NUZiY3FA00HKu5WTMhA                            Secrets
# 582  spotify:artist:5vMAKlvvMNSRQRYCAvpG6S  Same Devil (feat. Brandi Carlile)
#
#                                 album_uri  duration  \
# 0    spotify:album:1GYbbLzBosZi7MLG12iasq    187977
# 1    spotify:album:5ysULa9YY0ccEAZtxklzln    240920
# 2    spotify:album:40nTEfg3tTj1bptrG7IQU0    297410
# 3    spotify:album:3kaQUt8Mp906u1fI0LDqO6    208330
# 4    spotify:album:5Ck5a5KpFGdl6evWX5ENo8    200973
# ..                                    ...       ...
# 578  spotify:album:1XHEQqyatYvfK5cEJfkPeK    281773
# 579  spotify:album:5GUIokWQutqoCjNqn7PpNw    267280
# 580  spotify:album:1WBps8cIMT6LYVq5rYh5ze    230560
# 581  spotify:album:7mmdJJoGtwStzZImLRmRFS    223405
# 582  spotify:album:6XL1xCLdUOU6j35YspCkqO    187466
#
#                                             album_name  \
# 0                           First Time He Kissed a Boy
# 1                                      Wind Sand Stars
# 2                                     All American Boy
# 3                   The Original High (Deluxe Version)
# 4                                            The Works
# ..                                                 ...
# 578                 Ingénue (25th Anniversary Edition)
# 579                                                 Ma
# 580  Sometimes I Sit and Think, And Sometimes I Jus...
# 581                        Heart On My Sleeve (Deluxe)
# 582                  Same Devil (feat. Brandi Carlile)
#
#                           artists
# 0                     Kadie Elder
# 1                      Matt Alber
# 2                     Steve Grand
# 3                    Adam Lambert
# 4                           Queen
# ..                            ...
# 578                     k.d. lang
# 579                Ariane Moffatt
# 580              Courtney Barnett
# 581                  Mary Lambert
# 582  Brandy Clark, Brandi Carlile
#
# [583 rows x 9 columns]

# %%
new_df = pd.merge(testDF,featureDF, left_on = "track_uri", right_on= "id")
new_df.to_csv('../data/processed_data.csv')
